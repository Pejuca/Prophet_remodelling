# %%
# !pip install ipeadatapy -q
# !pip install prophet -q

# %%
# biblios genéricas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.api as qqplot
import random
import os

# Gráficas
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

## Estatísticas de ajuste:
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score

# Holt-Winters para tentar simular tendência!
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

import requests

# %%
from prophet import Prophet

# %% [markdown]
# 1. Puxando a série IBOV

# %%
# Puxando o IBOVESPA

ibov = pd.read_csv(
    './Bovespa Historical Data.csv'
)

ibov = ibov[[
    'Date', 'Price', 'Change %'
]]

ibov['Date'] = pd.to_datetime(
    ibov['Date'], format = '%m/%d/%Y'
)

ibov = ibov.sort_values(by = 'Date').reset_index(drop = True)

ibov['Price'] = ibov['Price'].str.replace('.', 'x', regex = False).str.replace(',', '.', regex = False).str.replace('x', '', regex = False)
ibov['Price'] = ibov['Price'].astype(float)

ibov['diff_1'] = ibov['Price'].pct_change()

ibov = ibov.rename(
    columns={
        'Price':'IBOV'
    }
)

ibov_select = ibov[[
    'Date', 'IBOV'
]]

ibov.tail()
# Out:
#          Date     IBOV Change %    diff_1
# 46 2024-11-01  125.668   -3.12% -0.031184
# 47 2024-12-01  120.283   -4.28% -0.042851
# 48 2025-01-01  126.135    4.86%  0.048652
# 49 2025-02-01  122.799   -2.64% -0.026448
# 50 2025-03-01  130.260    6.08%  0.060758

# %%
## Train split do merge sem diff
size_treino = int(len(ibov) -6)
train_ndiff = ibov.iloc[:size_treino].copy()
test_ndiff = ibov.iloc[size_treino:].copy()

# %%
train_ibov = train_ndiff[[
    'Date','IBOV'
]].reset_index(drop = True)

# %%
train_ibov['y'] = train_ibov['IBOV']
train_ibov['ds'] = pd.to_datetime(train_ibov['Date'])

train_ibov.tail()
# Out:
#          Date     IBOV        y         ds
# 40 2024-05-01  122.098  122.098 2024-05-01
# 41 2024-06-01  123.907  123.907 2024-06-01
# 42 2024-07-01  127.652  127.652 2024-07-01
# 43 2024-08-01  136.004  136.004 2024-08-01
# 44 2024-09-01  131.816  131.816 2024-09-01

# %% [markdown]
# 2. Modelo Prophet; Benchmark

# %%
model = Prophet()

model.fit(train_ibov)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp24jn69sp/s8tgxppc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp24jn69sp/2cpxpfxi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89160', 'data', 'file=/tmp/tmp24jn69sp/s8tgxppc.json', 'init=/tmp/tmp24jn69sp/2cpxpfxi.json', 'output', 'file=/tmp/tmp24jn69sp/prophet_modelx9xhxdj_/prophet_model-20250514004230.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 00:42:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:42:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
last_date = train_ibov['ds'].max()

future_dates = pd.date_range(start=last_date + pd.offsets.MonthBegin(1), periods=6, freq='MS')

future = pd.DataFrame({'ds': future_dates})

# concat
future = pd.concat([train_ibov, future], ignore_index=True)

# %%
forecast_prophet = model.predict(future)

# %%
model.plot(forecast_prophet)
plt.show()

# %%
model.plot_components(forecast_prophet)
plt.show()

# %%
model.seasonalities
# Out:
# OrderedDict([('yearly',
#               {'period': 365.25,
#                'fourier_order': 10,
#                'prior_scale': 10.0,
#                'mode': 'additive',
#                'condition_name': None})])

# %%
forecast_prophet[['ds', 'yhat']].head()
# Out:
#           ds        yhat
# 0 2021-01-01  118.298523
# 1 2021-02-01  112.628262
# 2 2021-03-01  118.120018
# 3 2021-04-01  114.265322
# 4 2021-05-01  114.939443

# %%
train_ndiff.reset_index(inplace = True)

# %%
plt.figure(figsize = (14,6))

sns.lineplot(
    data = train_ndiff,
    label = 'Teste',
    color = 'black',
    x='Date',
    y='IBOV'
)

sns.lineplot(
    data = test_ndiff,
    label = 'Treino',
    color = 'grey',
    x='Date',
    y='IBOV'
)

sns.lineplot(
    data = forecast_prophet,
    label = 'Modelo Prophet',
    color = 'blue',
    linestyle = 'dotted',
    x='ds',
    y='yhat'
)

plt.show()

# %%
print(mean_squared_error(
    forecast_prophet[forecast_prophet['ds'] >= test_ndiff['Date'].iloc[0]]['yhat'], test_ndiff['IBOV']
))
# Out:
# 54.2680777901519

# %% [markdown]
# 3. Testando a efetividade de um Holt-Winters, visto que captura tendência + sazonalidade

# %%
# Criando o Modelo
model_HW = ExponentialSmoothing(
    train_ndiff['IBOV'],
    trend='mul',
    seasonal='mul',
    seasonal_periods=12
).fit(optimized=True)

# %%
train_ndiff['fitted'] = model_HW.fittedvalues
forecast = model_HW.forecast(steps=6)

# %%
forecast
# Out:
# 45    129.844710
# 46    133.457820
# 47    136.380132
# 48    137.409880
# 49    134.239067
# 50    136.956290
# dtype: float64

# %%
fit_forecast = pd.concat([
    train_ndiff[[
    'Date', 'fitted'
]],
    pd.DataFrame({
    'Date': pd.to_datetime(test_ndiff['Date']),
    'fitted': forecast
})
])

fit_forecast.tail()
# Out:
#          Date      fitted
# 46 2024-11-01  133.457820
# 47 2024-12-01  136.380132
# 48 2025-01-01  137.409880
# 49 2025-02-01  134.239067
# 50 2025-03-01  136.956290

# %%
plt.figure(figsize = (14,6))

sns.lineplot(
    data = train_ndiff,
    label = 'Teste',
    color = 'black',
    x='Date',
    y='IBOV'
)

sns.lineplot(
    data = test_ndiff,
    label = 'Treino',
    color = 'grey',
    x='Date',
    y='IBOV'
)

sns.lineplot(
    data = fit_forecast,
    label = 'Holt-Winters - Fit e Forecast',
    color = 'blue',
    linestyle = 'dotted',
    x='Date',
    y='fitted'
)

plt.show()

# %%
print(mean_squared_error(
    forecast, test_ndiff['IBOV']
))
# Out:
# 103.7757772871506

# %% [markdown]
# 4. Tentando replicar o modelo!

# %% [markdown]
# A fórmula teórica do Prophet: y(t)=g(t)+s(t)+h(t)+εt​
#
# y(t) sendo a previsão -- montada a partir os componentes abaixo -- ;
#
# g(t) a tendência;
#
# s(t) a sazonalidade;
#
# h(t) os feriados e -- este iremos desconsiderar --;
#
# εt​ os erros

# %% [markdown]
# 4.1. Replicando a TREND

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

# %%
# O trend do Prophet é calculado com alguns changepoints; que são pontos nos quais a direção da série pode mudar

num_points = 3 # Usei 2 a princípio, mas 3 parecia permitir um formato melhor;

# Criando o vetor de tempo; que servirá como a única covariada para essa trend

X = pd.DataFrame([])

X['time'] = (train_ndiff['Date'] - train_ndiff['Date'].min()).dt.days

X.head()
# Out:
#    time
# 0     0
# 1    31
# 2    59
# 3    90
# 4   120

# %%
# No prophet, os changepoints são feitos em 80% do dataset;
  # Criaremos os changepoints linearmente com linspace
indices_points = np.linspace(
    0, int(len(train_ndiff) * 0.8), num_points +2, dtype = int
)[1:-1] # Adicionamos +2 e tiramos o 1 e -1 para que não tenhamos mudanças no início da série nem no final exato dos 80%

# Procuramos os indices equivalentes no df X (o do tempo)
changepoints = X['time'].iloc[indices_points].values

changepoints
# Out:
# array([273, 546, 820])

# %%
for i, cp in enumerate(changepoints):
    X[f'd_{i}'] = np.maximum(0, X['time'] - cp)

# %%
X
# Out:
#     time   d_0  d_1  d_2
# 0      0     0    0    0
# 1     31     0    0    0
# 2     59     0    0    0
# 3     90     0    0    0
# 4    120     0    0    0
# 5    151     0    0    0
# 6    181     0    0    0
# 7    212     0    0    0
# 8    243     0    0    0
# 9    273     0    0    0
# 10   304    31    0    0
# 11   334    61    0    0
# 12   365    92    0    0
# 13   396   123    0    0
# 14   424   151    0    0
# 15   455   182    0    0
# 16   485   212    0    0
# 17   516   243    0    0
# 18   546   273    0    0
# 19   577   304   31    0
# 20   608   335   62    0
# 21   638   365   92    0
# 22   669   396  123    0
# 23   699   426  153    0
# 24   730   457  184    0
# 25   761   488  215    0
# 26   789   516  243    0
# 27   820   547  274    0
# 28   850   577  304   30
# 29   881   608  335   61
# 30   911   638  365   91
# 31   942   669  396  122
# 32   973   700  427  153
# 33  1003   730  457  183
# 34  1034   761  488  214
# 35  1064   791  518  244
# 36  1095   822  549  275
# 37  1126   853  580  306
# 38  1155   882  609  335
# 39  1186   913  640  366
# 40  1216   943  670  396
# 41  1247   974  701  427
# 42  1277  1004  731  457
# 43  1308  1035  762  488
# 44  1339  1066  793  519

# %%
y = train_ndiff['IBOV'].values

# Fit da reglin
model_trend = LinearRegression().fit(X, y)

# %%
train_ndiff['trend'] = model_trend.predict(X)

# %%
plt.figure(figsize = (14,6))


sns.lineplot(
    data = train_ndiff,
    label = 'Trend',
    color = 'blue',
    linestyle = 'dotted',
    x='Date',
    y='trend'
)


plt.show()

# %%
# Removendo a trend do y para ser capturada da sazonalidade

y_detrend = y - train_ndiff['trend']

# %% [markdown]
# 4.2.1. Tentando encontrar a Sazonalidade de maneira simples usando a Série de Fourier, que é o que faz o próprio modelo Prophet
#
# Não posso mentir, aqui o ChatGPT teve que me dar uma boa ajuda

# %%
def fourier_series(t, period, order):
  """
  Gera componentes Fourier (seno e cosseno) para modelar sazonalidade periódica.

  Parâmetros:
  - t: vetor de tempo (em dias, por exemplo)
  - period: período da sazonalidade (ex: 365.25 para anual)
  - order: número de termos (quanto maior, mais complexo o padrão)

  Retorna:
  - Um array com 2 * order colunas (seno e cosseno para cada harmônico)
  """
  x = []
  for i in range(1, order + 1):
    x.append(np.sin(2 * np.pi * i * t / period))
    x.append(np.cos(2 * np.pi * i * t / period))
  return np.column_stack(x)

# %%
fourier_order = 10
X_fourier = pd.DataFrame(
    fourier_series(X['time'].values, period=365.25, order=fourier_order),
    columns=[f'sin_{i}' if j % 2 == 0 else f'cos_{i}'
             for i in range(1, fourier_order + 1) for j in range(2)]
)

# %%
sigma = 10.0
alpha = 1 / sigma**2  # Ridge uses alpha = λ = 1/σ²

# Fit model
model_season = Ridge(alpha=alpha, fit_intercept=False)
model_season.fit(X_fourier, y_detrend)
# Out:
# Ridge(alpha=0.01, fit_intercept=False)

# %%
X_fourier
# Out:
#        sin_1     cos_1     sin_2     cos_2     sin_3     cos_3     sin_4  \
# 0   0.000000  1.000000  0.000000  1.000000  0.000000  1.000000  0.000000
# 1   0.508356  0.861147  0.875539  0.483147  0.999579 -0.029025  0.846029
# 30 -0.288291  0.957543  0.323093 -0.946367 -0.357464  0.933927
# 31 -0.739392 -0.673275  0.970882  0.239557 -0.967711  0.252062
# 32  0.926430 -0.376467 -0.154204  0.988039 -0.767655 -0.640864
# 33 -0.196540  0.980496 -0.975336 -0.220724  0.244772 -0.969581
# 34 -0.799691 -0.600412  0.135055 -0.990838  0.931210 -0.364483
# 35  0.941759 -0.336289  0.979425  0.201808  0.732111  0.681185
# 36 -0.103031  0.994678 -0.115856  0.993266 -0.128661  0.991689
# 37 -0.852837 -0.522178 -0.999579 -0.029025 -0.881699  0.471812
# 38  0.955346 -0.295489  0.248940 -0.968519 -0.694452 -0.719539
# 39 -0.145700  0.989329  0.986501  0.163757  0.181760 -0.983343
# 40 -0.745156 -0.666890 -0.230151  0.973155  0.964945 -0.262452
# 41  0.923158 -0.384421 -0.989485 -0.144636  0.774500  0.632573
# 42 -0.188099  0.982150  0.211276 -0.977426 -0.234334  0.972156
# 43 -0.804826 -0.593511  0.992099  0.125461 -0.927238  0.374474
# 44  0.882712 -0.469915 -0.038696  0.999251 -0.843728 -0.536771

# %%
# enfim, temos que 'prever' a sazonalidade com uma regressão linear

#model_season = LinearRegression().fit(X_fourier, y)
train_ndiff['season_fourier'] = model_season.predict(X_fourier)

# %%
plt.figure(figsize = (14,6))


sns.lineplot(
    data = train_ndiff,
    label = 'Sazonalidade',
    color = 'blue',
    linestyle = 'dotted',
    x='Date',
    y='season_fourier'
)


plt.show()

# %%
# Somando as séries para capturar o fit final; compararemos com o fit do Prophet
  # Faremos o mesmo com regressão linear; O PREDICT AINDA NÃO ESTÁ AQUI!
train_ndiff['reconstr_1'] = train_ndiff['trend'] + train_ndiff['season_fourier']

train_ndiff.tail()
# Out:
#     index       Date     IBOV Change %    diff_1      fitted       trend  \
# 40     40 2024-05-01  122.098   -3.04% -0.030383  128.731427  128.676058
# 41     41 2024-06-01  123.907    1.48%  0.014816  121.931468  130.056763
# 42     42 2024-07-01  127.652    3.02%  0.030224  125.573255  131.392930
# 43     43 2024-08-01  136.004    6.54%  0.065428  128.999709  132.773635
# 44     44 2024-09-01  131.816   -3.08% -0.030793  132.850387  134.154340
#
#     season_fourier  reconstr_1
# 40       -1.148465  127.527593
# 41       -2.250922  127.805841
# 42       -2.020226  129.372703
# 43        4.246709  137.020344
# 44       -0.142605  134.011736

# %%
# Reconstruindo com Reg.Linear

X_rec = train_ndiff[['trend', 'season_fourier']].copy()
y = train_ndiff['IBOV']
model_rec = LinearRegression()
model_rec.fit(X_rec, y)

train_ndiff['reconstr_2'] = model_rec.predict(X_rec)

# %%
plt.figure(figsize = (14,6))

sns.lineplot(
    data = train_ndiff,
    label = 'Teste',
    color = 'black',
    x='Date',
    y='IBOV'
)

sns.lineplot(
    data = train_ndiff,
    label = 'Reconstrução 1',
    color = 'red',
    linestyle = 'dotted',
    x='Date',
    y='reconstr_1'
)

sns.lineplot(
    data = train_ndiff,
    label = 'Reconstrução 2',
    color = 'lime',
    linestyle = 'dotted',
    x='Date',
    y='reconstr_2'
)

sns.lineplot(
    data = forecast_prophet,
    label = 'Modelo Prophet',
    color = 'blue',
    linestyle = 'dotted',
    x='ds',
    y='yhat'
)

plt.show()
